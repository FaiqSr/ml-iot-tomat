# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Latihan Random Forest
# Cell ini menjalankan skrip training Random Forest yang dibuat di `src/train_random_forest.py`. Jalankan sel kode berikut untuk mulai melatih model pada `dataset_tomat.csv`.

# %%
# Jalankan training (pastikan kernel memakai virtualenv di `env`)
import subprocess, sys, os
# path relatif dari folder repo: src/train_random_forest.py
script = os.path.join(os.getcwd(), 'src', 'main.py')
print('Menjalankan:', script)
ret = subprocess.run([sys.executable, script])
print('Selesai dengan kode keluar', ret.returncode)
